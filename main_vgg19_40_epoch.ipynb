# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.losses import categorical_crossentropy

def VGG19(input_shape, class_num):
    """
    Creates a VGG19 model with the given input shape and number of classes.

    Parameters:
    input_shape (tuple): The shape of the input data (height, width, channels).
    class_num (int): The number of classes.

    Returns:
    keras.models.Sequential: The VGG19 model.
    """

    model = Sequential()

    #Convolution Layers
    model.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                        activation= 'relu', input_shape= input_shape))
    model.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))

    #Pooling Layer
    model.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))


    #Convolution Layers
    model.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))

    #Pooling Layer
    model.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

    #Convolution Layers
    model.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))

    #Pooling Layer
    model.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

    #Convolution Layers
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))

    #Pooling Layer
    model.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

    #Convolution Layers
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))
    model.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                    activation= 'relu'))

    #Pooling Layer
    model.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

    #Fully Connected Layers
    model.add(Flatten())
    model.add(Dense(4096, activation= 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation= 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(class_num, activation= 'softmax'))

    return model

# %%
"""
Mounts the Google Drive to the Colab notebook.
"""
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import random

training = []
Categories = ['Goals', 'Cards', 'Substitution']
path_test = '/content/drive/MyDrive/Football Major Event Detection/Datasets'
img_size = 224

def createTrainingData(Categories, img_size, path_test):
    """
    Create training data by resizing images from different categories.

    Parameters:
    Categories (list): List of categories.
    img_size (int): Size of the resized images.
    path_test (str): Path to the test images directory.

    Returns:
    None
    """
    for category in Categories:
        path = os.path.join(path_test, category)
        class_num = Categories.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path, img))
            new_array = cv2.resize(img_array, (img_size, img_size))
            training.append([new_array, class_num])

createTrainingData(Categories, img_size, path_test)
random.shuffle(training)

# %%
import numpy as np

classes_num = 3
X=[]
y=[]

def preprocess_data(training, img_size):
    """
    Preprocesses the training data by reshaping the features, normalizing the pixel values,
    and converting the labels to categorical format.

    Args:
        training (list): List of tuples containing features and labels.
        img_size (int): Size of the images.

    Returns:
        numpy.ndarray: Preprocessed features.
        numpy.ndarray: Preprocessed labels.
    """
    for features, label in training:
        X.append(features)
        y.append(label)

    X = np.array(X).reshape(-1, img_size, img_size, 3)

    X = X.astype('float32')
    X /= 255

    from keras.utils import to_categorical

    y = to_categorical(y, classes_num)

    return X, y

X, y = preprocess_data(training, img_size)

# %%
from sklearn.model_selection import train_test_split

def split_data(X, y):
    """
    Splits the data into training and testing sets using the train_test_split function from sklearn.

    Parameters:
    X (array-like): The input features.
    y (array-like): The target variable.

    Returns:
    X_train (array-like): The training set of input features.
    X_test (array-like): The testing set of input features.
    y_train (array-like): The training set of target variable.
    y_test (array-like): The testing set of target variable.
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
    return X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 4)

# %%
"""
Splitting the training data into validation and training sets.

Parameters:
- X_train: The input training data.
- y_train: The target training data.

Returns:
- x_val: The validation set of input data.
- x_train: The training set of input data.
- y_val: The validation set of target data.
- y_train: The training set of target data.
"""
x_val = X_train[:310]
x_train = X_train[310:]

y_val = y_train[:310]
y_train = y_train[310:]

# %%
model = VGG19((224,224,3), 3)
"""
Create a VGG19 model for event detection in soccer.

Parameters:
- input_shape: tuple, the shape of the input images (height, width, channels)
- num_classes: int, the number of event classes to predict

Returns:
- model: VGG19 model
"""

# %%
from keras import optimizers, losses, metrics

def compile_model(model):
    """
    Compiles the model with specified optimizer, loss function, and metrics.
    
    Parameters:
    model (keras.Model): The model to be compiled.
    
    Returns:
    None
    """
    model.compile(optimizer=optimizers.Adam(learning_rate=0.0001), loss=losses.categorical_crossentropy,
                  metrics=[metrics.categorical_crossentropy, metrics.categorical_accuracy])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 139582531 (532.47 MB)
# Trainable params: 139582531 (532.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def train_model(x_train, y_train, x_val, y_val):
    """
    Trains a model using the given training data and validation data.

    Args:
        x_train (numpy.ndarray): The input training data.
        y_train (numpy.ndarray): The target training data.
        x_val (numpy.ndarray): The input validation data.
        y_val (numpy.ndarray): The target validation data.

    Returns:
        The trained model.
    """
    trained_model = model.fit(x_train, y_train, epochs=40, batch_size=100, validation_data=(x_val, y_val))
    return trained_model

trained_model = train_model(x_train, y_train, x_val, y_val)
trained_model = model.fit(x_train,y_train, epochs=40, batch_size=100,validation_data=(x_val, y_val))
# Out:
# Epoch 1/40
# 10/10 [==============================] - 95s 4s/step - loss: 1.1309 - categorical_crossentropy: 1.1309 - categorical_accuracy: 0.4411 - val_loss: 1.0960 - val_categorical_crossentropy: 1.0960 - val_categorical_accuracy: 0.3871
# Epoch 2/40
# 10/10 [==============================] - 18s 2s/step - loss: 1.0963 - categorical_crossentropy: 1.0963 - categorical_accuracy: 0.3903 - val_loss: 1.0913 - val_categorical_crossentropy: 1.0913 - val_categorical_accuracy: 0.4806
# Epoch 3/40
# 10/10 [==============================] - 18s 2s/step - loss: 1.0907 - categorical_crossentropy: 1.0907 - categorical_accuracy: 0.4530 - val_loss: 1.0696 - val_categorical_crossentropy: 1.0696 - val_categorical_accuracy: 0.4806
# Epoch 4/40
# 10/10 [==============================] - 17s 2s/step - loss: 1.0743 - categorical_crossentropy: 1.0743 - categorical_accuracy: 0.4530 - val_loss: 1.0465 - val_categorical_crossentropy: 1.0465 - val_categorical_accuracy: 0.4806
# Epoch 5/40
# 10/10 [==============================] - 18s 2s/step - loss: 1.0718 - categorical_crossentropy: 1.0718 - categorical_accuracy: 0.4530 - val_loss: 1.0462 - val_categorical_crossentropy: 1.0462 - val_categorical_accuracy: 0.4806
# Epoch 6/40
# 10/10 [==============================] - 18s 2s/step - loss: 1.0582 - categorical_crossentropy: 1.0582 - categorical_accuracy: 0.4530 - val_loss: 1.0112 - val_categorical_crossentropy: 1.0112 - val_categorical_accuracy: 0.4806
# Epoch 7/40
# 10/10 [==============================] - 18s 2s/step - loss: 1.0141 - categorical_crossentropy: 1.0141 - categorical_accuracy: 0.4843 - val_loss: 0.9431 - val_categorical_crossentropy: 0.9431 - val_categorical_accuracy: 0.5452
# Epoch 8/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.8415 - categorical_crossentropy: 0.8415 - categorical_accuracy: 0.6216 - val_loss: 0.8427 - val_categorical_crossentropy: 0.8427 - val_categorical_accuracy: 0.5935
# Epoch 9/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.7502 - categorical_crossentropy: 0.7502 - categorical_accuracy: 0.6843 - val_loss: 0.7235 - val_categorical_crossentropy: 0.7235 - val_categorical_accuracy: 0.7194
# Epoch 10/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.6997 - categorical_crossentropy: 0.6997 - categorical_accuracy: 0.7059 - val_loss: 0.9356 - val_categorical_crossentropy: 0.9356 - val_categorical_accuracy: 0.6516
# Epoch 11/40
# 10/10 [==============================] - 17s 2s/step - loss: 0.7408 - categorical_crossentropy: 0.7408 - categorical_accuracy: 0.7157 - val_loss: 0.6776 - val_categorical_crossentropy: 0.6776 - val_categorical_accuracy: 0.7645
# Epoch 12/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.6031 - categorical_crossentropy: 0.6031 - categorical_accuracy: 0.7697 - val_loss: 0.6433 - val_categorical_crossentropy: 0.6433 - val_categorical_accuracy: 0.7710
# Epoch 13/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.5086 - categorical_crossentropy: 0.5086 - categorical_accuracy: 0.8000 - val_loss: 0.6148 - val_categorical_crossentropy: 0.6148 - val_categorical_accuracy: 0.7839
# Epoch 14/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.5192 - categorical_crossentropy: 0.5192 - categorical_accuracy: 0.7957 - val_loss: 0.5012 - val_categorical_crossentropy: 0.5012 - val_categorical_accuracy: 0.8161
# Epoch 15/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.4942 - categorical_crossentropy: 0.4942 - categorical_accuracy: 0.8141 - val_loss: 0.5220 - val_categorical_crossentropy: 0.5220 - val_categorical_accuracy: 0.8258
# Epoch 16/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.4544 - categorical_crossentropy: 0.4544 - categorical_accuracy: 0.8270 - val_loss: 0.5117 - val_categorical_crossentropy: 0.5117 - val_categorical_accuracy: 0.8226
# Epoch 17/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.3903 - categorical_crossentropy: 0.3903 - categorical_accuracy: 0.8595 - val_loss: 0.4653 - val_categorical_crossentropy: 0.4653 - val_categorical_accuracy: 0.8161
# Epoch 18/40
# 10/10 [==============================] - 17s 2s/step - loss: 0.3354 - categorical_crossentropy: 0.3354 - categorical_accuracy: 0.8681 - val_loss: 0.4263 - val_categorical_crossentropy: 0.4263 - val_categorical_accuracy: 0.8548
# Epoch 19/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.2817 - categorical_crossentropy: 0.2817 - categorical_accuracy: 0.8930 - val_loss: 0.3665 - val_categorical_crossentropy: 0.3665 - val_categorical_accuracy: 0.8581
# Epoch 20/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.2436 - categorical_crossentropy: 0.2436 - categorical_accuracy: 0.9059 - val_loss: 0.3704 - val_categorical_crossentropy: 0.3704 - val_categorical_accuracy: 0.8871
# Epoch 21/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.2233 - categorical_crossentropy: 0.2233 - categorical_accuracy: 0.9157 - val_loss: 0.3487 - val_categorical_crossentropy: 0.3487 - val_categorical_accuracy: 0.8935
# Epoch 22/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.1800 - categorical_crossentropy: 0.1800 - categorical_accuracy: 0.9308 - val_loss: 0.3678 - val_categorical_crossentropy: 0.3678 - val_categorical_accuracy: 0.9065
# Epoch 23/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.1500 - categorical_crossentropy: 0.1500 - categorical_accuracy: 0.9524 - val_loss: 0.3471 - val_categorical_crossentropy: 0.3471 - val_categorical_accuracy: 0.8903
# Epoch 24/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.1187 - categorical_crossentropy: 0.1187 - categorical_accuracy: 0.9568 - val_loss: 0.3949 - val_categorical_crossentropy: 0.3949 - val_categorical_accuracy: 0.9032
# Epoch 25/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0977 - categorical_crossentropy: 0.0977 - categorical_accuracy: 0.9686 - val_loss: 0.4300 - val_categorical_crossentropy: 0.4300 - val_categorical_accuracy: 0.8903
# Epoch 26/40
# 10/10 [==============================] - 19s 2s/step - loss: 0.1067 - categorical_crossentropy: 0.1067 - categorical_accuracy: 0.9676 - val_loss: 0.3912 - val_categorical_crossentropy: 0.3912 - val_categorical_accuracy: 0.8742
# Epoch 27/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.1312 - categorical_crossentropy: 0.1312 - categorical_accuracy: 0.9578 - val_loss: 0.4423 - val_categorical_crossentropy: 0.4423 - val_categorical_accuracy: 0.8968
# Epoch 28/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0880 - categorical_crossentropy: 0.0880 - categorical_accuracy: 0.9622 - val_loss: 0.4910 - val_categorical_crossentropy: 0.4910 - val_categorical_accuracy: 0.8806
# Epoch 29/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0589 - categorical_crossentropy: 0.0589 - categorical_accuracy: 0.9870 - val_loss: 0.4918 - val_categorical_crossentropy: 0.4918 - val_categorical_accuracy: 0.9000
# Epoch 30/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0532 - categorical_crossentropy: 0.0532 - categorical_accuracy: 0.9838 - val_loss: 0.6508 - val_categorical_crossentropy: 0.6508 - val_categorical_accuracy: 0.9129
# Epoch 31/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0582 - categorical_crossentropy: 0.0582 - categorical_accuracy: 0.9795 - val_loss: 0.6453 - val_categorical_crossentropy: 0.6453 - val_categorical_accuracy: 0.8710
# Epoch 32/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.1009 - categorical_crossentropy: 0.1009 - categorical_accuracy: 0.9730 - val_loss: 0.4074 - val_categorical_crossentropy: 0.4074 - val_categorical_accuracy: 0.9032
# Epoch 33/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0476 - categorical_crossentropy: 0.0476 - categorical_accuracy: 0.9827 - val_loss: 0.6078 - val_categorical_crossentropy: 0.6078 - val_categorical_accuracy: 0.9097
# Epoch 34/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0695 - categorical_crossentropy: 0.0695 - categorical_accuracy: 0.9773 - val_loss: 0.3790 - val_categorical_crossentropy: 0.3790 - val_categorical_accuracy: 0.9032
# Epoch 35/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0530 - categorical_crossentropy: 0.0530 - categorical_accuracy: 0.9870 - val_loss: 0.7100 - val_categorical_crossentropy: 0.7100 - val_categorical_accuracy: 0.8871
# Epoch 36/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0381 - categorical_crossentropy: 0.0381 - categorical_accuracy: 0.9816 - val_loss: 0.6213 - val_categorical_crossentropy: 0.6213 - val_categorical_accuracy: 0.9032
# Epoch 37/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0123 - categorical_crossentropy: 0.0123 - categorical_accuracy: 0.9957 - val_loss: 0.7598 - val_categorical_crossentropy: 0.7598 - val_categorical_accuracy: 0.9129
# Epoch 38/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0072 - categorical_crossentropy: 0.0072 - categorical_accuracy: 0.9968 - val_loss: 0.7233 - val_categorical_crossentropy: 0.7233 - val_categorical_accuracy: 0.9258
# Epoch 39/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0243 - categorical_crossentropy: 0.0243 - categorical_accuracy: 0.9957 - val_loss: 0.6846 - val_categorical_crossentropy: 0.6846 - val_categorical_accuracy: 0.9097
# Epoch 40/40
# 10/10 [==============================] - 18s 2s/step - loss: 0.0174 - categorical_crossentropy: 0.0174 - categorical_accuracy: 0.9914 - val_loss: 0.8245 - val_categorical_crossentropy: 0.8245 - val_categorical_accuracy: 0.8968

# %%
def get_trained_model_dict(trained_model):
    """
    Retrieves the history dictionary from a trained model.

    Parameters:
    trained_model (object): The trained model object.

    Returns:
    dict: The history dictionary of the trained model.
    """
    trained_model_dict = trained_model.history
    return trained_model_dict

trained_model_dict = get_trained_model_dict(trained_model)
trained_model_dict.keys()
# Out:
# dict_keys(['loss', 'categorical_crossentropy', 'categorical_accuracy', 'val_loss', 'val_categorical_crossentropy', 'val_categorical_accuracy'])

# %%
import matplotlib.pyplot as plt

def plot_loss(loss_value, val_loss_value):
    """
    Plots the training and validation loss over epochs.

    Parameters:
    loss_value (list): List of training loss values.
    val_loss_value (list): List of validation loss values.
    """
    epochs = range(1, len(loss_value) + 1)

    plt.plot(epochs, loss_value, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss_value, 'b', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
"""
Plots the training and validation accuracy over epochs.

Parameters:
- acc_values (list): List of training accuracy values.
- val_acc_values (list): List of validation accuracy values.
- epochs (list): List of epoch numbers.

Returns:
None
"""

acc_values = trained_model_dict['categorical_accuracy']
val_acc_values = trained_model_dict['val_categorical_accuracy']


plt.plot(epochs, acc_values, 'bo', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'b', label= 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
